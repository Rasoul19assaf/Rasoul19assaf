# %%
! pip install git+https://github.com/LIAAD/yake
# Out:
# Collecting git+https://github.com/LIAAD/yake
#   Cloning https://github.com/LIAAD/yake to /tmp/pip-req-build-k1f471df
#   Running command git clone -q https://github.com/LIAAD/yake /tmp/pip-req-build-k1f471df
#   fatal: unable to access 'https://github.com/LIAAD/yake/': Could not resolve host: github.com
# ERROR: Command "git clone -q https://github.com/LIAAD/yake /tmp/pip-req-build-k1f471df" failed with error code 128 in None

# %%
import yake
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-7cd11dc808be> in <module>
# ----> 1 import yake
#
# ModuleNotFoundError: No module named 'yake'

# %%
import pandas as pd
import yake_helper_funcs as yhf

forum_posts = pd.read_csv("../input/medium-articles/scrapped_articles.csv")

# get forum posts

# subsample forum posts
# sample_posts = forum_posts.text.astype(str)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-102d0d720b60> in <module>
#       1 import pandas as pd
# ----> 2 import yake_helper_funcs as yhf
#       3
#       4 forum_posts = pd.read_csv("../input/medium-articles/scrapped_articles.csv")
#       5
#
# /kaggle/usr/lib/yake_helper_funcs/yake_helper_funcs.py in <module>
#       5 import pandas as pd
#       6 from nltk.tokenize import RegexpTokenizer
# ----> 7 import yake
#       8
#       9 def keywords_yake(sample_posts):
#
# ModuleNotFoundError: No module named 'yake'

# %%
sample_posts = forum_posts.text.astype(str)

# %% [markdown]
# # Extract set of keywords from each post

# %%
# extact keywords & tokenize
keywords = yhf.keywords_yake(sample_posts)
keywords_tokenized = yhf.tokenizing_after_YAKE(keywords)
keyword_sets = [set(post) for post in keywords_tokenized]

# %% [markdown]
# # Get word vectors for keywords in post

# %%
vectors = pd.read_csv("../input/", 
                      delim_whitespace=True,
                      skiprows=[0], 
                      header=None
                     )

# set words as index rather than first column
vectors.index = vectors[0]
vectors.drop(0, axis=1, inplace=True)

# %%
def vectors_from_post(post):
    all_words = [] 

    for words in post:
        all_words.append(words) 
        
    return(vectors[vectors.index.isin(all_words)])

    
vectors_from_post(keyword_sets[0])

# %%
# test out getting forum post embedding (in the dumbest way possible)
test_vectors = vectors_from_post(keyword_sets[0])

test_vectors.mean()
